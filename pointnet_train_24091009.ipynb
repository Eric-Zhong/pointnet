# %% [markdown]
# # 准备开发环境

# %% [markdown]
# ## Tensor 安装并升级到最新版

# %%
# !pip install tensor --upgrade > /dev/null

# %% [markdown]
# ## Pandas 安装及升级到最新版

# %%
# !pip install pandas --upgrade > /dev/null
# !pip install bottleneck --upgrade > /dev/null

# %% [markdown]
# ## h5py 安装

# %%
# !pip install h5py --upgrade > /dev/null

# %% [markdown]
# ## provider 安装及升级

# %%
# !pip install provider --upgrade > /dev/null

# %% [markdown]
# ## tf_util

# %%
# !pip install tf_util --upgrade > /dev/null
# Out:
# ERROR: Could not find a version that satisfies the requirement tf_util (from versions: none)
# ERROR: No matching distribution found for tf_util

# %%
# !git clone https://github.com/Eric-Zhong/pointnet.git
# %cd pointnet
# Out:
#   origin/HEAD -> origin/master
#   origin/dev
#   origin/master

# %%
# !git branch --remotes
# Out:
#   origin/HEAD -> origin/master
#   origin/dev
#   origin/master

# %%
# !git checkout -b dev
# Out:
# Switched to a new branch 'dev'

# %%
# !git branch
# Out:
# * dev
#   master

# %%
# !git pull origin dev

# %% [markdown]
# # PointNet

# %% [markdown]
# ## Import

# %%
import argparse
import math
import h5py
import numpy as np
import tensorflow as tf
import socket
import importlib
import os
import sys
import provider
import tf_util
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-0bef2788d729> in <cell line: 11>()
#       9 import sys
#      10 import provider
# ---> 11 import tf_util
#
# ModuleNotFoundError: No module named 'tf_util'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Environment Variable

# %%
if '__file__' in globals():
    BASE_DIR = os.path.dirname(os.path.abspath(__file__))
    sys.path.append(BASE_DIR)
    sys.path.append(os.path.join(BASE_DIR, 'models'))
    sys.path.append(os.path.join(BASE_DIR, 'utils'))
